# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from bs4 import BeautifulSoup
import requests
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
webpage=requests.get("https://pgdekho.com/pg-in-delhi").text
soup=BeautifulSoup(webpage,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="/favicon.ico" rel="icon"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#000000" name="theme-color"/>
#   <link href="/logo192.png" rel="apple-touch-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="xcoSE-io14yrqOSHCXLP6X2KBy_4-ubg8JnAaIjriRs" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {
#       "@context": "https://schema.org",
#       "@type": "Organization",
#       "name": "PGâ¯Dekho",
#       "alternateName": "PGâ¯Dekho India",
#       "url": "https://pgdekho.com/",
#       "logo": "https://pgdekho.com/static/media/footer-logo.fc7248ab26cdb010c6c5.png",
#       "description": "PG Dekho is an online platform that helps working professionals and students find paying guest (PG) accommodations, coâliving spaces and rental flats across India.",
#       "foundingDate": "2017",
#       "contactPoint": [
#         {
#           "@type": "ContactPoint",
#           "telephone": "+91â96438â40007",
#           "contactType": "customer support",
#           "areaServed": "IN",
#           "availableLanguage": ["English", "Hindi"]
#         }
#       ],
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "C/o Kanchan Thakran, W/o Rajbir Thakran, Neelâ¯Kanth Enclv B/p Badshahpur",
#         "addressLocality": "Gurugram",
#         "addressRegion": "Haryana",
#         "postalCode": "122101",
#         "addressCountry": "IN"
#       },
#       "sameAs": [
#         "https://www.linkedin.com/company/pg-dekho",
#         "https://www.facebook.com/pgdekhoindia/",
#         "https://www.instagram.com/pgdekhoindia/",
#         "https://twitter.com/pgdekhoindia"
#       ]
#     }
#   </script>
#   <script type="application/ld+json">
#    {
#       "@context": "https://schema.org",
#       "@type": "LocalBusiness",
#       "@id": "https://pgdekho.com/#LocalBusiness",
#       "name": "PG Dekho",
#       "alternateName": "PG Dekho",
#       "legalName": "Roomer Technologies Private Limited",
#       "description": "Find affordable, verified PGs for boys, girls, couples, and students with PG Dekho. Enjoy homely food, safety, and comfort across India. Explore single rooms, shared or co-living spaces designed for modern living your trusted home starts here!",
#       "foundingDate": "2010-01-01",
#       "image": "https://pgdekho.com/static/media/guest-room-1.6971e2a84b9f89a87f1a.png",
#       "logo": "https://pgdekho.com/static/media/Website_Logo.d1d59fa38ed475764498.png",
#       "url": "https://pgdekho.com/",
#       "telephone": "+91 9643840007",
#       "email": "info@pgdekho.com",
#       "priceRange": "$$",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "1910, 19th Floor, Magnum Global Park, Golf Course Ext Rd",
#         "addressLocality": "Sector 58, Gurugram",
#         "postalCode": "122011",
#         "addressRegion": "HR",
#         "addressCountry": "IN"
#       }
#     }
#   </script>
#   <script type="application/ld+json">
#    {
#       "@context": "https://schema.org",
#       "@type": "FAQPage",
#       "mainEntity": [
#         {
#           "@type": "Question",
#           "name": "What makes PG Dekho the best platform to find PGs in India?",
#           "acceptedAnswer": {
#             "@type": "Answer",
#             "text": "PG Dekho helps you find verified and affordable PGs across India for boys, girls, couples, and students. With food, safety, and comfort guaranteed, you can explore single rooms or co-living options all in one trusted place."
#           }
#         },
#         {
#           "@type": "Question",
#           "name": "How do I find affordable PGs with food and safety across India?",
#           "acceptedAnswer": {
#             "@type": "Answer",
#             "text": "Use PG Dekho to explore budget-friendly PGs offering homely meals, verified listings, and secure stays. Whether you need a single room, shared accommodation, or co-living, PG Dekho makes it easy to book trusted homes nationwide."
#           }
#         },
#         {
#           "@type": "Question",
#           "name": "Does PG Dekho offer PGs for couples and students too?",
#           "acceptedAnswer": {
#             "@type": "Answer",
#             "text": "Yes! PG Dekho lists verified PGs for couples, students, boys, and girls, all with essential amenities, food, and security. Discover flexible and affordable options across India suited to your lifestyle and comfort needs."
#           }
#         },
#         {
#           "@type": "Question",
#           "name": "Why choose co-living spaces on PG Dekho?",
#           "acceptedAnswer": {
#             "@type": "Answer",
#             "text": "PG Dekhoâs co-living options combine affordability, community, and comfort. Enjoy furnished rooms, shared amenities, and homely food while living with like-minded people, perfect for professionals, students, and couples."
#           }
#         },
#         {
#           "@type": "Question",
#           "name": "Is PG Dekho available in all major cities in India?",
#           "acceptedAnswer": {
#             "@type": "Answer",
#             "text": "Absolutely, PG Dekho helps you find PGs and co-living spaces across Indiaâs top cities, including Delhi, Bangalore, Noida, and Gurgaon. Enjoy verified listings, affordable rent, and hassle-free booking anywhere you move."
#           }
#         }
#       ]
#     }
#   </script>
#   <script>
#    !function(e,t,n,c,o,a,f){e.fbq||(o=e.fbq=function(){o.callMethod?o.callMethod.apply(o,arguments):o.queue.push(arguments)},e._fbq||(e._fbq=o),o.push=o,o.loaded=!0,o.version="2.0",o.queue=[],(a=t.createElement(n)).async=!0,a.src="https://connect.facebook.net/en_US/fbevents.js",(f=t.getElementsByTagName(n)[0]).parentNode.insertBefore(a,f))}(window,document,"script"),fbq("init","1406674093676988"),fbq("track","PageView")
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1406674093676988&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-1E6WMBFJZ7">
#   </script>
#   <script>
#    function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","G-1E6WMBFJZ7")
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-17380595176">
#   </script>
#   <script>
#    function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","AW-17380595176")
#   </script>
#   <script>
#    var url="https://wati-integration-prod-service.clare.ai/v2/watiWidget.js?88324",s=document.createElement("script");s.type="text/javascript",s.async=!0,s.src=url;var options={enabled:!0,chatButtonSetting:{backgroundColor:"#00e785",borderRadius:"25",marginLeft:"0",marginRight:"20",marginBottom:"20",ctaIconWATI:!1,position:"right"},brandSetting:{brandName:"PG Dekho",brandSubTitle:"undefined",brandImg:"https://www.wati.io/wp-content/uploads/2023/04/Wati-logo.svg",welcomeText:"Hi there!\nHow can I help you?",messageText:"",backgroundColor:"#00e785",ctaText:"Chat with us",borderRadius:"25",autoShow:!1,phoneNumber:"9643840006"}};s.onload=function(){CreateWhatsappChatWidget(options)};var x=document.getElementsByTagName("script")[0];x.parentNode.insertBefore(s,x)
#   </script>
#   <title>
#    PG Dekho | Find Paying Guest &amp; Coliving Across India
#   </title>
#   <meta content="PG Dekho helps you find verified PGs and coliving spaces across India." data-rh="true" name="description"/>
#   <script defer="defer" src="/static/js/main.9fac4a9c.js">
#   </script>
#   <link href="/static/css/main.76e583cb.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <noscript>
#    You need to enable JavaScript to run this app.
#   </noscript>
#   <div id="root">
#   </div>
#   <script src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js">
#   </script>
#   <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyB0oVP9ASJypwf7BLW86zTwqqM2iSI0DuE&amp;libraries=places&amp;language=en">
#   </script>
#   <script src="https://checkout.razorpay.com/v1/checkout.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-EWCD0TQF88">
#   </script>
#   <script>
#    function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","G-EWCD0TQF88")
#   </script>
#  </body>
# </html>

# %%
for i in soup.find_all('div', class_="pg-card-wrapper seo-page-card"):
  print(i.text.strip())
